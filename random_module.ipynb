# %%
import numpy as np

# %%
np.random.random() #Give random float number between 0<num<1
# Out:
# 0.7962136907365037

# %%
np.random.uniform(1,10) #Give random float num between 1 and 10
# Out:
# 3.3413622895440396

# %%
np.random.randint(1,20) #Give random integer between 1 and 20
# Out:
# 8

# %%
arr1 = np.random.randint(1,100,10).reshape(2,5) #Generate array of 10 random numbers between 1 and 100

# %%
arr1
# Out:
# array([[ 7, 71, 11,  2,  8],
#        [83, 25, 87, 83, 26]], dtype=int32)

# %%
np.max(arr1) #Give max number of array
# Out:
# np.int32(87)

# %%
np.argmax(arr1) #Giive index of max number of array
# Out:
# np.int64(7)
