# %%
import numpy as np

# %%
a1 = np.arange(9).reshape(3,3) #3  rows

# %%
a2 = np.arange(3).reshape(1,3) #only one row

# %%
print(a1 , a2)
# Out:
# [[0 1 2]
#  [3 4 5]
#  [6 7 8]] [[0 1 2]]

# %%
a1 + a2 #Add one row of a1 to each row of a2
# Out:
# array([[ 0,  2,  4],
#        [ 3,  5,  7],
#        [ 6,  8, 10]])
