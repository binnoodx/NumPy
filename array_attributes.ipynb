# %%
import numpy as np

# %%
#arr1.copy() ----> Function
#arr1.shapt -----> Attribute
arr1 = np.array([1,2,3,4,5])
arr1.shape
arr1.ndim
# Out:
# 1

# %%
arr2 = np.array([[1,2,3] , [4,5,6]])
arr2.shape #give shape of array
arr2.ndim #give dimension of array
# Out:
# 2

# %%
arr3 = np.array([ [[1,2] , [3,4]] , [[5,6] , [7,8]] ]) #3d Array
arr3.shape
# Out:
# (2, 2, 2)

# %%
arr3.ndim
# Out:
# 3

# %%
arr3.size #gives no of elements
# Out:
# 8

# %%
arr3.itemsize #gives the size of elements of array
# Out:
# 8

# %%
arr3.dtype
# Out:
# dtype('int64')

# %%
arr3.astype('float')
# Out:
# array([[[1., 2.],
#         [3., 4.]],
#
#        [[5., 6.],
#         [7., 8.]]])
