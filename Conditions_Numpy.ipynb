# %%
import numpy as np

# %%
arr = np.array([[1,2,3] ,[4,5,6]])

# %%
arr[arr%2 == 0] = 69 #Change the numbers of arrays to 69 which are even
arr
# Out:
# array([[ 1, 69,  3],
#        [69,  5, 69]])

# %%
a2 = np.arange(9).reshape(3,3)

# %%
np.where(a2%2==1 , 36 , a2) #np.where(condition , TrueStatememt , FalseStatement)
# Out:
# array([[ 0, 36,  2],
#        [36,  4, 36],
#        [ 6, 36,  8]])
